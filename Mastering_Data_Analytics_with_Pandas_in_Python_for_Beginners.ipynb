# %% [markdown]
# <a href="https://colab.research.google.com/github/baacumen/baacumen-learning/blob/main/Mastering_Data_Analytics_with_Pandas_in_Python_for_Beginners.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Let's start by creating the sample CSV file and then proceed with the steps:

# %%
import pandas as pd

# Create a sample DataFrame
data = {
    'Customer_ID': [1, 2, 3, 4, 5],
    'Customer_Name': ['John', 'Alice', 'Bob', 'Emily', 'Michael'],
    'Age': [30, 25, 35, 40, 28],
    'Gender': ['M', 'F', 'M', 'F', 'M'],
    'City': ['New York', 'Los Angeles', 'Chicago', 'Houston', 'San Francisco'],
    'State': ['NY', 'CA', 'IL', 'TX', 'CA'],
    'Zip_Code': [10001, 90001, 60601, 77001, 94101],
    'Product_ID': [101, 102, 103, 104, 105],
    'Product_Name': ['Shirt', 'Shoes', 'Watch', 'Bag', 'Hat'],
    'Category': ['Apparel', 'Footwear', 'Accessories', 'Accessories', 'Apparel'],
    'Quantity': [2, 1, 1, 3, 2],
    'Price_per_unit': [20.0, 50.0, 100.0, 30.0, 15.0],
    'Total_Price': [40.0, 50.0, 100.0, 90.0, 30.0],
    'Date': ['2024-01-01', '2024-01-02', '2024-01-03', '2024-01-04', '2024-01-05']
}

# Convert data into DataFrame
df = pd.DataFrame(data)

# Save DataFrame to CSV file
df.to_csv('sample_data.csv', index=False)

# %% [markdown]
# We will now proceed with the steps outlined in the article:

# %%
# 1. Import the necessary libraries
import pandas as pd

# 2. Read the CSV file into a Pandas DataFrame
data = pd.read_csv('sample_data.csv')

# %%
# 3. Perform each step outlined in the guide
# 3.1. Displaying the first few rows
print("First few rows:\n")
data.head(2) # specifying to print first two rows
# Out:
# First few rows:
#    Customer_ID Customer_Name  Age Gender         City State  Zip_Code  \
# 0            1          John   30      M     New York    NY     10001
# 1            2         Alice   25      F  Los Angeles    CA     90001
#
#    Product_ID Product_Name  Category  Quantity  Price_per_unit  Total_Price  \
# 0         101        Shirt   Apparel         2            20.0         40.0
# 1         102        Shoes  Footwear         1            50.0         50.0
#
#          Date
# 0  2024-01-01
# 1  2024-01-02

# %%
# 3.2. Displaying the last few rows
print("Last few rows:\n")
data.tail(2) # specifying to print last two rows
# Out:
# Last few rows:
#    Customer_ID Customer_Name  Age Gender           City State  Zip_Code  \
# 3            4         Emily   40      F        Houston    TX     77001
# 4            5       Michael   28      M  San Francisco    CA     94101
#
#    Product_ID Product_Name     Category  Quantity  Price_per_unit  \
# 3         104          Bag  Accessories         3            30.0
# 4         105          Hat      Apparel         2            15.0
#
#    Total_Price        Date
# 3         90.0  2024-01-04
# 4         30.0  2024-01-05

# %%
# 3.3. Displaying data information
print("\nData information:")
print(data.info())
# Out:
# Data information:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 14 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Customer_ID     5 non-null      int64
#  1   Customer_Name   5 non-null      object
#  2   Age             5 non-null      int64
#  3   Gender          5 non-null      object
#  4   City            5 non-null      object
#  5   State           5 non-null      object
#  6   Zip_Code        5 non-null      int64
#  7   Product_ID      5 non-null      int64
#  8   Product_Name    5 non-null      object
#  9   Category        5 non-null      object
#  10  Quantity        5 non-null      int64
#  11  Price_per_unit  5 non-null      float64
#  12  Total_Price     5 non-null      float64
#  13  Date            5 non-null      object
# dtypes: float64(2), int64(5), object(7)
# memory usage: 688.0+ bytes
# None

# %%
# 3.4. Displaying descriptive statistics
print("\nDescriptive statistics:")
print(data.describe())
# Out:
# Descriptive statistics:
#        Customer_ID       Age      Zip_Code  Product_ID  Quantity  \
# count     5.000000   5.00000      5.000000    5.000000   5.00000
# mean      3.000000  31.60000  66341.000000  103.000000   1.80000
# std       1.581139   5.94138  34099.824046    1.581139   0.83666
# min       1.000000  25.00000  10001.000000  101.000000   1.00000
# 25%       2.000000  28.00000  60601.000000  102.000000   1.00000
# 50%       3.000000  30.00000  77001.000000  103.000000   2.00000
# 75%       4.000000  35.00000  90001.000000  104.000000   2.00000
# max       5.000000  40.00000  94101.000000  105.000000   3.00000
#
#        Price_per_unit  Total_Price
# count        5.000000     5.000000
# mean        43.000000    62.000000
# std         34.568772    31.144823
# min         15.000000    30.000000
# 25%         20.000000    40.000000
# 50%         30.000000    50.000000
# 75%         50.000000    90.000000
# max        100.000000   100.000000

# %%
# 3.5. Displaying the dimensions of the data
print("\nDimensions of the data:")
print(data.shape)
# Out:
# Dimensions of the data:
# (5, 14)

# %%
# 3.6. Positional Indexing
print("\nPositional indexing:")
print(data.iloc[0])
# Out:
# Positional indexing:
# Customer_ID                1
# Customer_Name           John
# Age                       30
# Gender                     M
# City                New York
# State                     NY
# Zip_Code               10001
# Product_ID               101
# Product_Name           Shirt
# Category             Apparel
# Quantity                   2
# Price_per_unit          20.0
# Total_Price             40.0
# Date              2024-01-01
# Name: 0, dtype: object

# %%
# 3.7. Label-Based Indexing
print("\nLabel-based indexing:")
print(data.loc[:, 'Customer_Name'])
# Out:
# Label-based indexing:
# 0       John
# 1      Alice
# 2        Bob
# 3      Emily
# 4    Michael
# Name: Customer_Name, dtype: object

# %%
# 3.8. Filtering data based on conditions
print("\nFiltering data based on conditions:")
filtered_data = data[data['Category'].isin(['Apparel', 'Footwear'])]
filtered_data
# Out:
# Filtering data based on conditions:
#    Customer_ID Customer_Name  Age Gender           City State  Zip_Code  \
# 0            1          John   30      M       New York    NY     10001
# 1            2         Alice   25      F    Los Angeles    CA     90001
# 4            5       Michael   28      M  San Francisco    CA     94101
#
#    Product_ID Product_Name  Category  Quantity  Price_per_unit  Total_Price  \
# 0         101        Shirt   Apparel         2            20.0         40.0
# 1         102        Shoes  Footwear         1            50.0         50.0
# 4         105          Hat   Apparel         2            15.0         30.0
#
#          Date
# 0  2024-01-01
# 1  2024-01-02
# 4  2024-01-05

# %%
# 3.9. Grouping and aggregating data
print("\nGrouping and aggregating data:")
grouped_data = data.groupby('Category')['Total_Price'].mean()
grouped_data
# Out:
# Grouping and aggregating data:
# Category
# Accessories    95.0
# Apparel        35.0
# Footwear       50.0
# Name: Total_Price, dtype: float64

# %%
# 3.10. Merging datasets
print("\nMerging datasets:")
data1 = data[['Customer_ID', 'Customer_Name']]
data2 = data[['Customer_ID', 'City', 'State']]
merged_data = pd.merge(data1, data2, on='Customer_ID')
merged_data
# Out:
# Merging datasets:
#    Customer_ID Customer_Name           City State
# 0            1          John       New York    NY
# 1            2         Alice    Los Angeles    CA
# 2            3           Bob        Chicago    IL
# 3            4         Emily        Houston    TX
# 4            5       Michael  San Francisco    CA

# %%
# 3.11. Creating a pivot table
print("\nCreating a pivot table:")
pivot_table_data = data.pivot_table(index='Category', columns='Date', values='Total_Price', aggfunc='sum')
pivot_table_data
# Out:
# Creating a pivot table:
# Date         2024-01-01  2024-01-02  2024-01-03  2024-01-04  2024-01-05
# Category
# Accessories         NaN         NaN       100.0        90.0         NaN
# Apparel            40.0         NaN         NaN         NaN        30.0
# Footwear            NaN        50.0         NaN         NaN         NaN

# %%
# 3.12. Dropping missing values
print("\nDropping missing values:")
cleaned_data = data.dropna()
cleaned_data
# Out:
# Dropping missing values:
#    Customer_ID Customer_Name  Age Gender           City State  Zip_Code  \
# 0            1          John   30      M       New York    NY     10001
# 1            2         Alice   25      F    Los Angeles    CA     90001
# 2            3           Bob   35      M        Chicago    IL     60601
# 3            4         Emily   40      F        Houston    TX     77001
# 4            5       Michael   28      M  San Francisco    CA     94101
#
#    Product_ID Product_Name     Category  Quantity  Price_per_unit  \
# 0         101        Shirt      Apparel         2            20.0
# 1         102        Shoes     Footwear         1            50.0
# 2         103        Watch  Accessories         1           100.0
# 3         104          Bag  Accessories         3            30.0
# 4         105          Hat      Apparel         2            15.0
#
#    Total_Price        Date
# 0         40.0  2024-01-01
# 1         50.0  2024-01-02
# 2        100.0  2024-01-03
# 3         90.0  2024-01-04
# 4         30.0  2024-01-05

# %%
# 3.13. Filling missing values
print("\nFilling missing values:")
filled_data = data.fillna(0)  # Replace missing values with 0
filled_data
# Out:
# Filling missing values:
#    Customer_ID Customer_Name  Age Gender           City State  Zip_Code  \
# 0            1          John   30      M       New York    NY     10001
# 1            2         Alice   25      F    Los Angeles    CA     90001
# 2            3           Bob   35      M        Chicago    IL     60601
# 3            4         Emily   40      F        Houston    TX     77001
# 4            5       Michael   28      M  San Francisco    CA     94101
#
#    Product_ID Product_Name     Category  Quantity  Price_per_unit  \
# 0         101        Shirt      Apparel         2            20.0
# 1         102        Shoes     Footwear         1            50.0
# 2         103        Watch  Accessories         1           100.0
# 3         104          Bag  Accessories         3            30.0
# 4         105          Hat      Apparel         2            15.0
#
#    Total_Price        Date
# 0         40.0  2024-01-01
# 1         50.0  2024-01-02
# 2        100.0  2024-01-03
# 3         90.0  2024-01-04
# 4         30.0  2024-01-05

# %%
# 3.14. Applying a custom transformation
print("\nApplying a custom transformation:")
def double_price(x):
    return x * 2
data['Double_Price'] = data['Price_per_unit'].apply(double_price)
data
# Out:
# Applying a custom transformation:
#    Customer_ID Customer_Name  Age Gender           City State  Zip_Code  \
# 0            1          John   30      M       New York    NY     10001
# 1            2         Alice   25      F    Los Angeles    CA     90001
# 2            3           Bob   35      M        Chicago    IL     60601
# 3            4         Emily   40      F        Houston    TX     77001
# 4            5       Michael   28      M  San Francisco    CA     94101
#
#    Product_ID Product_Name     Category  Quantity  Price_per_unit  \
# 0         101        Shirt      Apparel         2            20.0
# 1         102        Shoes     Footwear         1            50.0
# 2         103        Watch  Accessories         1           100.0
# 3         104          Bag  Accessories         3            30.0
# 4         105          Hat      Apparel         2            15.0
#
#    Total_Price        Date  Double_Price
# 0         40.0  2024-01-01          40.0
# 1         50.0  2024-01-02         100.0
# 2        100.0  2024-01-03         200.0
# 3         90.0  2024-01-04          60.0
# 4         30.0  2024-01-05          30.0

# %%
# 3.15. Displaying counts of unique values
print("\nDisplaying counts of unique values:")
print(data['Category'].value_counts())
# Out:
# Displaying counts of unique values:
# Apparel        2
# Accessories    2
# Footwear       1
# Name: Category, dtype: int64

# %%
# 3.16. Sorting data
print("\nSorting data:")
sorted_data = data.sort_values(by='Total_Price', ascending=False)
sorted_data
# Out:
# Sorting data:
#    Customer_ID Customer_Name  Age Gender           City State  Zip_Code  \
# 2            3           Bob   35      M        Chicago    IL     60601
# 3            4         Emily   40      F        Houston    TX     77001
# 1            2         Alice   25      F    Los Angeles    CA     90001
# 0            1          John   30      M       New York    NY     10001
# 4            5       Michael   28      M  San Francisco    CA     94101
#
#    Product_ID Product_Name     Category  Quantity  Price_per_unit  \
# 2         103        Watch  Accessories         1           100.0
# 3         104          Bag  Accessories         3            30.0
# 1         102        Shoes     Footwear         1            50.0
# 0         101        Shirt      Apparel         2            20.0
# 4         105          Hat      Apparel         2            15.0
#
#    Total_Price        Date  Double_Price
# 2        100.0  2024-01-03         200.0
# 3         90.0  2024-01-04          60.0
# 1         50.0  2024-01-02         100.0
# 0         40.0  2024-01-01          40.0
# 4         30.0  2024-01-05          30.0

# %%
# Plotting data
import matplotlib.pyplot as plt

# Plotting a histogram of the 'Total_Price' column
plt.hist(data['Total_Price'], bins=10, color='skyblue', edgecolor='black')
plt.title('Histogram of Total Prices')
plt.xlabel('Total Price')
plt.ylabel('Frequency')
plt.show()

# Calculating correlations
correlation_matrix = data.corr()
print("Correlation Matrix:")
print(correlation_matrix)
# Out:
# Correlation Matrix:
#                 Customer_ID       Age  Zip_Code  Product_ID  Quantity  \
# Customer_ID        1.000000  0.292735  0.719631    1.000000  0.377964
# Age                0.292735  1.000000 -0.118361    0.292735  0.583394
# Zip_Code           0.719631 -0.118361  1.000000    0.719631 -0.063617
# Product_ID         1.000000  0.292735  0.719631    1.000000  0.377964
# Quantity           0.377964  0.583394 -0.063617    0.377964  1.000000
# Price_per_unit    -0.137217  0.214231  0.046319   -0.137217 -0.665576
# Total_Price        0.101535  0.802515  0.034745    0.101535  0.019188
# Double_Price      -0.137217  0.214231  0.046319   -0.137217 -0.665576
#
#                 Price_per_unit  Total_Price  Double_Price
# Customer_ID          -0.137217     0.101535     -0.137217
# Age                   0.214231     0.802515      0.214231
# Zip_Code              0.046319     0.034745      0.046319
# Product_ID           -0.137217     0.101535     -0.137217
# Quantity             -0.665576     0.019188     -0.665576
# Price_per_unit        1.000000     0.724477      1.000000
# Total_Price           0.724477     1.000000      0.724477
# Double_Price          1.000000     0.724477      1.000000
# <ipython-input-19-a56aef93585d>:12: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   correlation_matrix = data.corr()

# %%
# 4. Save the modified DataFrame to a new CSV file
data.to_csv('processed_data.csv', index=False)
